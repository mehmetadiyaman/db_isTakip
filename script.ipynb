-- %% [markdown]
-- # [DbisTAKİP]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DbisTAKİP]    Script Date: 19.02.2024 17:59:06 ******/
CREATE DATABASE [DbisTAKİP]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'DbisTAKİP', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\DbisTAKİP.mdf' , SIZE = 73728KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'DbisTAKİP_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\DbisTAKİP_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [DbisTAKİP] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DbisTAKİP].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DbisTAKİP] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [DbisTAKİP] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [DbisTAKİP] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [DbisTAKİP] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [DbisTAKİP] SET ARITHABORT OFF 
GO
ALTER DATABASE [DbisTAKİP] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [DbisTAKİP] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [DbisTAKİP] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [DbisTAKİP] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [DbisTAKİP] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [DbisTAKİP] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [DbisTAKİP] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [DbisTAKİP] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [DbisTAKİP] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [DbisTAKİP] SET  DISABLE_BROKER 
GO
ALTER DATABASE [DbisTAKİP] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [DbisTAKİP] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [DbisTAKİP] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [DbisTAKİP] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [DbisTAKİP] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [DbisTAKİP] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [DbisTAKİP] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [DbisTAKİP] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [DbisTAKİP] SET  MULTI_USER 
GO
ALTER DATABASE [DbisTAKİP] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [DbisTAKİP] SET DB_CHAINING OFF 
GO
ALTER DATABASE [DbisTAKİP] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [DbisTAKİP] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [DbisTAKİP] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [DbisTAKİP] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [DbisTAKİP] SET QUERY_STORE = ON
GO
ALTER DATABASE [DbisTAKİP] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[tblCagriDetay]

-- %%
USE [DbisTAKİP]
GO

-- %%
/****** Object:  Table [dbo].[tblCagriDetay]    Script Date: 19.02.2024 17:59:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblCagriDetay](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Cagri] [int] NULL,
	[Aciklama] [nvarchar](max) NULL,
	[Tarih] [date] NULL,
	[saat] [char](10) NULL,
 CONSTRAINT [PK_tblCagriDetay] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblCagrilar]

-- %%
/****** Object:  Table [dbo].[tblCagrilar]    Script Date: 19.02.2024 17:59:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblCagrilar](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[CagriFirma] [int] NULL,
	[Konu] [nvarchar](50) NULL,
	[Aciklama] [nvarchar](max) NULL,
	[Durum] [bit] NULL,
	[Tarih] [date] NULL,
	[CagriPersonel] [int] NULL,
 CONSTRAINT [PK_tblCagrilar] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblDepartmanlar]

-- %%
/****** Object:  Table [dbo].[tblDepartmanlar]    Script Date: 19.02.2024 17:59:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblDepartmanlar](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Ad] [nvarchar](30) NULL,
 CONSTRAINT [PK_tblDepartmanlar] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblFirmalar]

-- %%
/****** Object:  Table [dbo].[tblFirmalar]    Script Date: 19.02.2024 17:59:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblFirmalar](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Ad] [nvarchar](30) NULL,
	[Yetkili] [nvarchar](30) NULL,
	[mail] [nvarchar](30) NULL,
	[Telefon] [nvarchar](20) NULL,
	[Sifre] [nvarchar](30) NULL,
	[Sektor] [nvarchar](30) NULL,
	[İl] [nvarchar](20) NULL,
	[İlce] [nvarchar](30) NULL,
	[Adres] [nvarchar](100) NULL,
	[Gorsel] [nvarchar](200) NULL,
 CONSTRAINT [PK_tblFirmalar] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblGorevDetaylar]

-- %%
/****** Object:  Table [dbo].[tblGorevDetaylar]    Script Date: 19.02.2024 17:59:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblGorevDetaylar](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Gorev] [int] NULL,
	[Aciklama] [nvarchar](200) NULL,
	[Tarih] [date] NULL,
	[Saat] [char](5) NULL,
 CONSTRAINT [PK_tblGorevDetaylar] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblGorevler]

-- %%
/****** Object:  Table [dbo].[tblGorevler]    Script Date: 19.02.2024 17:59:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblGorevler](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[GorevVeren] [int] NULL,
	[GorevAlan] [int] NULL,
	[Aciklama] [nvarchar](500) NULL,
	[Durum] [bit] NULL,
	[Tarih] [date] NULL,
 CONSTRAINT [PK_tblGorevler] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblMesajlar]

-- %%
/****** Object:  Table [dbo].[tblMesajlar]    Script Date: 19.02.2024 17:59:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblMesajlar](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Gonderen] [int] NULL,
	[Alici] [int] NULL,
	[Konu] [nvarchar](50) NULL,
	[Mesaj] [nvarchar](max) NULL,
	[Tarih] [date] NULL,
	[Durum] [bit] NULL,
 CONSTRAINT [PK_tblMesajlar] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblPersonel]

-- %%
/****** Object:  Table [dbo].[tblPersonel]    Script Date: 19.02.2024 17:59:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblPersonel](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Ad] [nvarchar](50) NULL,
	[Soyad] [nvarchar](50) NULL,
	[Mail] [nvarchar](50) NULL,
	[Telefon] [nvarchar](50) NULL,
	[Departman] [int] NULL,
	[Durum] [bit] NULL,
	[Sifre] [nvarchar](50) NULL,
	[Admin] [bit] NULL,
 CONSTRAINT [PK_tblPersonel] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_tblCagriDetay_tblCagrilar]

-- %%
ALTER TABLE [dbo].[tblCagriDetay]  WITH CHECK ADD  CONSTRAINT [FK_tblCagriDetay_tblCagrilar] FOREIGN KEY([Cagri])
REFERENCES [dbo].[tblCagrilar] ([ID])
GO
ALTER TABLE [dbo].[tblCagriDetay] CHECK CONSTRAINT [FK_tblCagriDetay_tblCagrilar]
GO

-- %% [markdown]
-- # [FK_tblCagrilar_tblFirmalar]

-- %%
ALTER TABLE [dbo].[tblCagrilar]  WITH CHECK ADD  CONSTRAINT [FK_tblCagrilar_tblFirmalar] FOREIGN KEY([CagriFirma])
REFERENCES [dbo].[tblFirmalar] ([ID])
GO
ALTER TABLE [dbo].[tblCagrilar] CHECK CONSTRAINT [FK_tblCagrilar_tblFirmalar]
GO

-- %% [markdown]
-- # [FK_tblCagrilar_tblPersonel]

-- %%
ALTER TABLE [dbo].[tblCagrilar]  WITH CHECK ADD  CONSTRAINT [FK_tblCagrilar_tblPersonel] FOREIGN KEY([CagriPersonel])
REFERENCES [dbo].[tblPersonel] ([ID])
GO
ALTER TABLE [dbo].[tblCagrilar] CHECK CONSTRAINT [FK_tblCagrilar_tblPersonel]
GO

-- %% [markdown]
-- # [FK_tblGorevDetaylar_tblGorevler1]

-- %%
ALTER TABLE [dbo].[tblGorevDetaylar]  WITH CHECK ADD  CONSTRAINT [FK_tblGorevDetaylar_tblGorevler1] FOREIGN KEY([Gorev])
REFERENCES [dbo].[tblGorevler] ([ID])
GO
ALTER TABLE [dbo].[tblGorevDetaylar] CHECK CONSTRAINT [FK_tblGorevDetaylar_tblGorevler1]
GO

-- %% [markdown]
-- # [FK_tblGorevler_tblPersonel]

-- %%
ALTER TABLE [dbo].[tblGorevler]  WITH CHECK ADD  CONSTRAINT [FK_tblGorevler_tblPersonel] FOREIGN KEY([GorevVeren])
REFERENCES [dbo].[tblPersonel] ([ID])
GO
ALTER TABLE [dbo].[tblGorevler] CHECK CONSTRAINT [FK_tblGorevler_tblPersonel]
GO

-- %% [markdown]
-- # [FK_tblGorevler_tblPersonel1]

-- %%
ALTER TABLE [dbo].[tblGorevler]  WITH CHECK ADD  CONSTRAINT [FK_tblGorevler_tblPersonel1] FOREIGN KEY([GorevAlan])
REFERENCES [dbo].[tblPersonel] ([ID])
GO
ALTER TABLE [dbo].[tblGorevler] CHECK CONSTRAINT [FK_tblGorevler_tblPersonel1]
GO

-- %% [markdown]
-- # [FK_tblMesajlar_tblFirmalar]

-- %%
ALTER TABLE [dbo].[tblMesajlar]  WITH CHECK ADD  CONSTRAINT [FK_tblMesajlar_tblFirmalar] FOREIGN KEY([Gonderen])
REFERENCES [dbo].[tblFirmalar] ([ID])
GO
ALTER TABLE [dbo].[tblMesajlar] CHECK CONSTRAINT [FK_tblMesajlar_tblFirmalar]
GO

-- %% [markdown]
-- # [FK_tblMesajlar_tblFirmalar1]

-- %%
ALTER TABLE [dbo].[tblMesajlar]  WITH CHECK ADD  CONSTRAINT [FK_tblMesajlar_tblFirmalar1] FOREIGN KEY([Alici])
REFERENCES [dbo].[tblFirmalar] ([ID])
GO
ALTER TABLE [dbo].[tblMesajlar] CHECK CONSTRAINT [FK_tblMesajlar_tblFirmalar1]
GO

-- %% [markdown]
-- # [FK_tblPersonel_tblDepartmanlar]

-- %%
ALTER TABLE [dbo].[tblPersonel]  WITH CHECK ADD  CONSTRAINT [FK_tblPersonel_tblDepartmanlar] FOREIGN KEY([Departman])
REFERENCES [dbo].[tblDepartmanlar] ([ID])
GO
ALTER TABLE [dbo].[tblPersonel] CHECK CONSTRAINT [FK_tblPersonel_tblDepartmanlar]
GO

-- %% [markdown]
-- # [DbisTAKİP]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DbisTAKİP] SET  READ_WRITE 
GO
